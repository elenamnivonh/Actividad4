# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cufflinks as cf
from IPython.display import display,HTML
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Carga de base de datos
data = pd.read_csv("COVID19OK.csv")
# Out:
# /var/folders/nc/68rf91wx2pjbt67gbj6chn7h0000gn/T/ipykernel_83398/37949041.py:2: DtypeWarning:
#
# Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
#Filtro por filas
data= data.iloc[0:100000,: ]
data
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2     NaN         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         NaN
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
#        SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  ...  OTRO_CASO  \
# 0       2.0           27           23            8.0  ...        2.0
# 1       2.0           25           25            1.0  ...        2.0
# 2       1.0            9            9           14.0  ...        2.0
# 3       1.0            9            9            2.0  ...        1.0
# 4       1.0            9            9            7.0  ...        1.0
# ...     ...          ...          ...            ...  ...        ...
# 99995   1.0           11           15           31.0  ...        2.0
# 99996   2.0           15           15           95.0  ...        1.0
# 99997   2.0           28           28           22.0  ...        1.0
# 99998   1.0           15            9            6.0  ...        1.0
# 99999   1.0            9            9            7.0  ...        2.0
#
#       TOMA_MUESTRA_LAB RESULTADO_LAB TOMA_MUESTRA_ANTIGENO  \
# 0                    2            97                     1
# 1                    2            97                     1
# 2                    1             1                     2
# 3                    2            97                     1
# 4                    2            97                     1
# ...                ...           ...                   ...
# 99995                1             2                     1
# 99996                2            97                     1
# 99997                2            97                     1
# 99998                2            97                     1
# 99999                2            97                     1
#
#        RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# 0                     2.0                    7        99             México
# 1                     2.0                    7        99             México
# 2                    97.0                    3        99             México
# 3                     2.0                    7        99             México
# 4                     2.0                    7        99             México
# ...                   ...                  ...       ...                ...
# 99995                 2.0                    7        99             México
# 99996                 2.0                    7        99             México
# 99997                 1.0                    3        99             México
# 99998                 1.0                    3        99             México
# 99999                 1.0                    3        99             México
#
#        PAIS_ORIGEN  UCI
# 0               97   97
# 1               97   97
# 2               97   97
# 3               97   97
# 4               97   97
# ...            ...  ...
# 99995           97   97
# 99996           97   97
# 99997           97   97
# 99998           97   97
# 99999           97   97
#
# [100000 rows x 41 columns]

# %%
#Identificación de valores nulos
valoresnull=data.isnull().sum()
valoresnull
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   1
# ENTIDAD_UM               1
# SEXO                     1
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            1
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     3
# NACIONALIDAD             0
# EMBARAZO                 2
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# TOMA_MUESTRA_ANTIGENO    0
# RESULTADO_ANTIGENO       1
# CLASIFICACION_FINAL      0
# MIGRANTE                 0
# PAIS_NACIONALIDAD        2
# PAIS_ORIGEN              0
# UCI                      0
# dtype: int64

# %%
#Copia de data frame
datacopy=data.copy()

# %% [markdown]
# *ELIMINACIÓN DE NULOS*
#
# SUSTITUCIÓN CON MEDIA

# %%
#SECTOR
datacopy["SECTOR"]=datacopy["SECTOR"].fillna(round(data["SECTOR"].mean(),1))

# %%
#Sustitución de NA media
#ENTIDAD_UM
datacopy["ENTIDAD_UM"]=datacopy["ENTIDAD_UM"].fillna(round(data["ENTIDAD_UM"].mean(),1))

# %%
#Sustitución de NA media
#Sexo
datacopy["SEXO"]=datacopy["SEXO"].fillna(round(data["SEXO"].mean(),1))

# %%
#Sustitución de NA media
#MUNICIPIO_RES
datacopy["MUNICIPIO_RES"]=datacopy["MUNICIPIO_RES"].fillna(round(data["MUNICIPIO_RES"].mean(),1))

# %%
#Sustitución de NA bfill
#EDAD
datacopy["EDAD"]=datacopy["EDAD"].fillna(method="bfill")

# %%
#Sustitución de NA bfill
#EMBARAZO
datacopy["EMBARAZO"]=datacopy["EMBARAZO"].fillna(method="bfill")

# %%
#Sustitución de NA bfill
#HIPERTENSION
datacopy["HIPERTENSION"]=datacopy["HIPERTENSION"].fillna(method="bfill")

# %%
#Sustitución de NA bfill
#PAIS_NACIONALIDAD
datacopy["PAIS_NACIONALIDAD"]=datacopy["PAIS_NACIONALIDAD"].fillna(method="bfill")

# %%
#Sustituir NA ffill
#TABAQUISMO
datacopy["TABAQUISMO"]=datacopy["TABAQUISMO"].fillna(method="ffill")

# %%
#Sustituir NA ffill
#OTRO_CASO
datacopy["OTRO_CASO"]=datacopy["OTRO_CASO"].fillna(method="ffill")

# %%
#Sustituir NA ffill
#RESULTADO_ANTIGENO
datacopy["RESULTADO_ANTIGENO"]=datacopy["RESULTADO_ANTIGENO"].fillna(method="ffill")

# %%
#Identificación de valores nulos
valoresnull=datacopy.isnull().sum()
valoresnull
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     0
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            0
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 0
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             0
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               0
# OTRO_CASO                0
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# TOMA_MUESTRA_ANTIGENO    0
# RESULTADO_ANTIGENO       0
# CLASIFICACION_FINAL      0
# MIGRANTE                 0
# PAIS_NACIONALIDAD        0
# PAIS_ORIGEN              0
# UCI                      0
# dtype: int64

# %% [markdown]
# *VALORES ATÍPICOS*

# %%
#Diagrama de caja para la identificación de outliers
fig = plt.figure(figsize =(5, 3)) 
plt.boxplot(datacopy["EDAD"]) 
plt.title("Edad COVID")
plt.show()

# %% [markdown]
# *ELIMINAR OUTLIERS CON DESVIACIÓN ESTANDAR*

# %%
#Método aplicando desviación estandar. 
y=datacopy["EDAD"]
LS= y.mean() + 2.309*y.std() 
LI= y.mean() - 2.309*y.std()
print("Limite superior permitido", LS)
print("Limite inferior permitido", LI)
# Out:
# Limite superior permitido 73.77864997319185
# Limite inferior permitido 0.0002100268081406398

# %%
#Identificación de Outliers 
outliers=datacopy[(y>LS)|(y<LI)]
outliers
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 36             36          27/08/2022      1a1ba9       2    12.0         2.0
# 43             43          27/08/2022       94015       1    12.0        21.0
# 49             49          27/08/2022      1e1717       2     6.0         9.0
# 51             51          27/08/2022      100caf       1     6.0        17.0
# ...           ...                 ...         ...     ...     ...         ...
# 99645       99645          27/08/2022      da14b0       2    12.0         9.0
# 99663       99663          27/08/2022      7edf6f       2    12.0        27.0
# 99699       99699          27/08/2022      73d65b       1    12.0        25.0
# 99871       99871          27/08/2022      e9623e       2     4.0        27.0
# 99914       99914          27/08/2022      52d37f       2    12.0        11.0
#
#        SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  ...  OTRO_CASO  \
# 1       2.0           25           25            1.0  ...        2.0
# 36      1.0           25            2            2.0  ...        1.0
# 43      2.0           21           21           49.0  ...        1.0
# 49      2.0           13            9           16.0  ...        2.0
# 51      1.0           21           17            1.0  ...        2.0
# ...     ...          ...          ...            ...  ...        ...
# 99645   1.0            9            9           15.0  ...        1.0
# 99663   2.0           27           27            8.0  ...        1.0
# 99699   2.0           25           25            1.0  ...        2.0
# 99871   2.0           27           27            4.0  ...        2.0
# 99914   1.0           11           11           17.0  ...        1.0
#
#       TOMA_MUESTRA_LAB RESULTADO_LAB TOMA_MUESTRA_ANTIGENO  \
# 1                    2            97                     1
# 36                   2            97                     1
# 43                   2            97                     1
# 49                   1             2                     2
# 51                   2            97                     1
# ...                ...           ...                   ...
# 99645                2            97                     1
# 99663                1             2                     2
# 99699                1             1                     2
# 99871                2            97                     1
# 99914                2            97                     1
#
#        RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# 1                     2.0                    7        99             México
# 36                    1.0                    3        99             México
# 43                    2.0                    7        99             México
# 49                   97.0                    7        99             México
# 51                    2.0                    1        99             México
# ...                   ...                  ...       ...                ...
# 99645                 1.0                    3        99             México
# 99663                97.0                    7        99             México
# 99699                97.0                    3        99             México
# 99871                 1.0                    3        99             México
# 99914                 1.0                    3        99             México
#
#        PAIS_ORIGEN  UCI
# 1               97   97
# 36              97   97
# 43              97   97
# 49              97    2
# 51              97    2
# ...            ...  ...
# 99645           97   97
# 99663           97   97
# 99699           97    2
# 99871           97   97
# 99914           97   97
#
# [2072 rows x 41 columns]

# %%
#Obtenemos datos sin outliers del DataFrame
data2=datacopy[(y<=LS)&(y>=LI)]
data2
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# 5               5          27/08/2022    7.41E+06       2     6.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2     8.1         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0        13.9
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
#        SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  ...  OTRO_CASO  \
# 0       2.0           27           23            8.0  ...        2.0
# 2       1.0            9            9           14.0  ...        2.0
# 3       1.0            9            9            2.0  ...        1.0
# 4       1.0            9            9            7.0  ...        1.0
# 5       2.0            9            9           16.0  ...        1.0
# ...     ...          ...          ...            ...  ...        ...
# 99995   1.0           11           15           31.0  ...        2.0
# 99996   2.0           15           15           95.0  ...        1.0
# 99997   2.0           28           28           22.0  ...        1.0
# 99998   1.0           15            9            6.0  ...        1.0
# 99999   1.0            9            9            7.0  ...        2.0
#
#       TOMA_MUESTRA_LAB RESULTADO_LAB TOMA_MUESTRA_ANTIGENO  \
# 0                    2            97                     1
# 2                    1             1                     2
# 3                    2            97                     1
# 4                    2            97                     1
# 5                    1             4                     2
# ...                ...           ...                   ...
# 99995                1             2                     1
# 99996                2            97                     1
# 99997                2            97                     1
# 99998                2            97                     1
# 99999                2            97                     1
#
#        RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# 0                     2.0                    7        99             México
# 2                    97.0                    3        99             México
# 3                     2.0                    7        99             México
# 4                     2.0                    7        99             México
# 5                    97.0                    2        99             México
# ...                   ...                  ...       ...                ...
# 99995                 2.0                    7        99             México
# 99996                 2.0                    7        99             México
# 99997                 1.0                    3        99             México
# 99998                 1.0                    3        99             México
# 99999                 1.0                    3        99             México
#
#        PAIS_ORIGEN  UCI
# 0               97   97
# 2               97   97
# 3               97   97
# 4               97   97
# 5               97    2
# ...            ...  ...
# 99995           97   97
# 99996           97   97
# 99997           97   97
# 99998           97   97
# 99999           97   97
#
# [97928 rows x 41 columns]

# %%
#Reemplazamos valores atípicos del dataframe con "mean"
#Realizamos una copia del dataframe
dataco=data2.fillna(round(data2.mean(),1))
dataco
# Out:
# /var/folders/nc/68rf91wx2pjbt67gbj6chn7h0000gn/T/ipykernel_83398/1868243592.py:3: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# 5               5          27/08/2022    7.41E+06       2     6.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2     8.1         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0        13.9
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
#        SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  ...  OTRO_CASO  \
# 0       2.0           27           23            8.0  ...        2.0
# 2       1.0            9            9           14.0  ...        2.0
# 3       1.0            9            9            2.0  ...        1.0
# 4       1.0            9            9            7.0  ...        1.0
# 5       2.0            9            9           16.0  ...        1.0
# ...     ...          ...          ...            ...  ...        ...
# 99995   1.0           11           15           31.0  ...        2.0
# 99996   2.0           15           15           95.0  ...        1.0
# 99997   2.0           28           28           22.0  ...        1.0
# 99998   1.0           15            9            6.0  ...        1.0
# 99999   1.0            9            9            7.0  ...        2.0
#
#       TOMA_MUESTRA_LAB RESULTADO_LAB TOMA_MUESTRA_ANTIGENO  \
# 0                    2            97                     1
# 2                    1             1                     2
# 3                    2            97                     1
# 4                    2            97                     1
# 5                    1             4                     2
# ...                ...           ...                   ...
# 99995                1             2                     1
# 99996                2            97                     1
# 99997                2            97                     1
# 99998                2            97                     1
# 99999                2            97                     1
#
#        RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# 0                     2.0                    7        99             México
# 2                    97.0                    3        99             México
# 3                     2.0                    7        99             México
# 4                     2.0                    7        99             México
# 5                    97.0                    2        99             México
# ...                   ...                  ...       ...                ...
# 99995                 2.0                    7        99             México
# 99996                 2.0                    7        99             México
# 99997                 1.0                    3        99             México
# 99998                 1.0                    3        99             México
# 99999                 1.0                    3        99             México
#
#        PAIS_ORIGEN  UCI
# 0               97   97
# 2               97   97
# 3               97   97
# 4               97   97
# 5               97    2
# ...            ...  ...
# 99995           97   97
# 99996           97   97
# 99997           97   97
# 99998           97   97
# 99999           97   97
#
# [97928 rows x 41 columns]

# %%
#Comprobación de limpieza exitosa
#Corroboramos valores nulos
valoresnull=dataco.isnull().sum()
valoresnull
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     0
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            0
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 0
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             0
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               0
# OTRO_CASO                0
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# TOMA_MUESTRA_ANTIGENO    0
# RESULTADO_ANTIGENO       0
# CLASIFICACION_FINAL      0
# MIGRANTE                 0
# PAIS_NACIONALIDAD        0
# PAIS_ORIGEN              0
# UCI                      0
# dtype: int64
